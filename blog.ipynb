# %% [raw]
# ---
# title: Ricardo Ruiz Sánchez
# subtitle: probando
# image: media/github_avatar.png
# about:
#   template: trestles
#   links:
#     - icon: bi-envelope-at
#       text: Email
#       href: mailto:email@email.com
#     - icon: bi-linkedin
#       text: Linkedin
#       href: https://www.linkedin.com/in/ricardo-r-s
#     - icon: github
#       text: Github
#       href: https://github.com
# toc: false # remove "On this page" table of contents
# ---

# %% [markdown]
# ```{css, echo=FALSE}
# .title {
#   font-size: 100px;
#   font-style: italic;
#   color: blue;
#   font-family: Arial;
#   font-variant: small-caps;
# }
# ```
#
#
#
# Data-driven environmental scientist with a passion for geographical information data. Started collecting data from the laboratory as a technician, I graduated in Environmental Sciences understanding the value of making informed-decisions towards a sustainable future. Along this journey I lived in Scotland and Germany. Drafted by the interest on geospatial data from the GIMA1 master, I am enthusiastic to land an internship in a GIS working environment.
#
# ## Education
# [{{< iconify zondicons education >}}]{style="color: #179498;"} Msc in Geographical Information Management and Applications
#
#
# [{{< iconify zondicons education >}}]{style="color: #179498;"} Bsc in Environmental Sciences
#
#
# [{{< iconify zondicons education >}}]{style="color: #179498;"} Higher vocational training as Laboratory technician in quality control
#
# ## Languages
#
# {{< iconify circle-flags uk >}} English (C1, advance)
#
#
# {{< iconify emojione flag-for-germany >}} German (B1, intermediate)
#
#
# {{< iconify emojione flag-for-spain >}} Spanish (Native)
